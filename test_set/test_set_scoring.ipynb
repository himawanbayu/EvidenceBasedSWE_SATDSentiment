# %%
from google.colab import drive, userdata
from huggingface_hub import login

drive.mount('/content/drive')
login(userdata.get('HF_TOKEN'))
# Out:
# Mounted at /content/drive

# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax
import pandas as pd
import numpy as np

# %%
# https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis
roberta = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(roberta)
config = AutoConfig.from_pretrained(roberta)
r_model = AutoModelForSequenceClassification.from_pretrained(roberta)
# r_model.save_pretrained(f"/content/drive/MyDrive/Uni stuff/Evidence-based/{roberta}")
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def compute_sentiment(model, encoded_input):
    try:
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        top_score = np.max(scores)
        sentiment = config.id2label[np.argmax(scores)]
        return sentiment, top_score
    except Exception as e:
        print(f"Error {e} processing encoded input: {encoded_input}")
        return None, None

def handle_long_text(model, text):
    max_length = 512
    encoded_input = tokenizer(text, return_tensors='pt')
    input_ids = encoded_input['input_ids'][0]

    if len(input_ids) > max_length:
        parts = [input_ids[i:i + max_length] for i in range(0, len(input_ids), max_length)]
        sentiments = []
        scores = []
        for part in parts:
            part_encoded_input = {'input_ids': part.unsqueeze(0)}
            sentiment, score = compute_sentiment(model, part_encoded_input)
            sentiments.append(sentiment)
            scores.append(score)

        sentiment = max(set(sentiments), key=sentiments.count)
        score = max(scores)
        return sentiment, score
    else:
        return compute_sentiment(model, encoded_input)

# %%
csv_file = "/content/drive/MyDrive/Uni stuff/Evidence-based/Dataset/satd-different-sources-data/satd-dataset-issues.csv"
data = pd.read_csv(csv_file)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23180 entries, 0 to 23179
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   project         23180 non-null  object
#  1   issue_number    23180 non-null  int64
#  2   issue_type      23180 non-null  object
#  3   text            23036 non-null  object
#  4   classification  23180 non-null  object
#  5   indicator       23180 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#   project  issue_number   issue_type  \
# 0   camel         10009    comment_0
# 1   camel         10009  description
# 2   camel         10009      summary
# 3   camel         10022    comment_0
# 4   camel         10022    comment_1
#
#                                                 text classification indicator
# 0                           If you use then it works       non_debt         -
# 1  If you use spring and then refer to an endpoin...       non_debt         -
# 2                   Using <to> with id and ref fails       non_debt         -
# 3             There is a basic health indicator now.       non_debt         -
# 4  We need the health check API in camel-core for...       non_debt         -

# %%
data = data.dropna(subset=['text'])
test_df = data.sample(n=30, random_state=1)

# %%
test_df[['sentiment', 'score']] = test_df['text'].apply(lambda x: pd.Series(handle_long_text(r_model, x)))
test_df.head()
# Out:
#       project  issue_number   issue_type  \
# 18508  impala          1027    comment_0
# 8003   gerrit          6215  description
# 12604  hadoop          7684    comment_7
# 14430   hbase         12833   comment_16
# 17600   hbase          6184    comment_8
#
#                                                     text classification  \
# 18508                      this is only for CTAS, right?       non_debt
# 8003   1. View a file that has a collapsed section an...       non_debt
# 12604  rpm package doesnt seem to include the history...      code_debt
# 14430  I guess it could be, but won't connections sti...      test_debt
# 17600  This can be happened when region split. 0.94.x...       non_debt
#
#               indicator sentiment     score
# 18508                 -   neutral  0.940757
# 8003                  -  negative  0.609213
# 12604  low_quality_code   neutral  0.509126
# 14430      low_coverage  negative  0.550618
# 17600                 -   neutral  0.755957

# %%
chunk_size = 50
num_chunks = len(data) // chunk_size + (1 if len(data) % chunk_size != 0 else 0)

for i in range(num_chunks):
    chunk = data.iloc[i * chunk_size:(i + 1) * chunk_size].copy()
    chunk[['sentiment', 'score']] = chunk['text'].apply(lambda x: pd.Series(handle_long_text(x)))
    if i == 0:
        chunk.to_csv(csv_file, index=False, mode='w', header=True)
    else:
        chunk.to_csv(csv_file, index=False, mode='a', header=False)
    print(f'Processed chunk {i + 1}/{num_chunks}')
# Out:
# Processed chunk 1/461
# Processed chunk 1/461
# Processed chunk 2/461
# Processed chunk 2/461
# Processed chunk 3/461
# Processed chunk 3/461
# Processed chunk 4/461
# Processed chunk 4/461
# Processed chunk 5/461
# Processed chunk 5/461
# Processed chunk 6/461
# Processed chunk 6/461
# Processed chunk 7/461
# Processed chunk 7/461
# Processed chunk 8/461
# Processed chunk 8/461
# Processed chunk 9/461
# Processed chunk 9/461
# Processed chunk 10/461
# Processed chunk 10/461
# Processed chunk 11/461
# Processed chunk 11/461
# Processed chunk 12/461
# Processed chunk 12/461
# Processed chunk 13/461
# Processed chunk 13/461
# Processed chunk 14/461
# Processed chunk 14/461
# Processed chunk 15/461
# Processed chunk 15/461
# Processed chunk 16/461
# Processed chunk 16/461
# Processed chunk 17/461
# Processed chunk 17/461
# Processed chunk 18/461
# Processed chunk 18/461
# Processed chunk 19/461
# Processed chunk 19/461
# Processed chunk 20/461
# Processed chunk 20/461
# Processed chunk 21/461
# Processed chunk 21/461
# Processed chunk 22/461
# Processed chunk 22/461
# Processed chunk 23/461
# Processed chunk 23/461
# Processed chunk 24/461
# Processed chunk 24/461
# Processed chunk 25/461
# Processed chunk 25/461
# Processed chunk 26/461
# Processed chunk 26/461
# Processed chunk 27/461
# Processed chunk 27/461
# Processed chunk 28/461
# Processed chunk 28/461
# Processed chunk 29/461
# Processed chunk 29/461
# Processed chunk 30/461
# Processed chunk 30/461
# Processed chunk 31/461
# Processed chunk 31/461
# Processed chunk 32/461
# Processed chunk 32/461
# Processed chunk 33/461
# Processed chunk 33/461
# Processed chunk 34/461
# Processed chunk 34/461
# Processed chunk 35/461
# Processed chunk 35/461
# Processed chunk 36/461
# Processed chunk 36/461
# Processed chunk 37/461
# Processed chunk 37/461
# Processed chunk 38/461
# Processed chunk 38/461
# Processed chunk 39/461
# Processed chunk 39/461
# Processed chunk 40/461
# Processed chunk 40/461
# Processed chunk 41/461
# Processed chunk 41/461
# Processed chunk 42/461
# Processed chunk 42/461
# Processed chunk 43/461
# Processed chunk 43/461
# Processed chunk 44/461
# Processed chunk 44/461
# Processed chunk 45/461
# Processed chunk 45/461
# Processed chunk 46/461
# Processed chunk 46/461
# Processed chunk 47/461
# Processed chunk 47/461
# Processed chunk 48/461
# Processed chunk 48/461
# Processed chunk 49/461
# Processed chunk 49/461
# Processed chunk 50/461
# Processed chunk 50/461
# Processed chunk 51/461
# Processed chunk 51/461
# Processed chunk 52/461
# Processed chunk 52/461
# Processed chunk 53/461
# Processed chunk 53/461
# Processed chunk 54/461
# Processed chunk 54/461
# Processed chunk 55/461
# Processed chunk 55/461
# Processed chunk 56/461
# Processed chunk 56/461
# Processed chunk 57/461
# Processed chunk 57/461
# Processed chunk 58/461
# Processed chunk 58/461
# Processed chunk 59/461
# Processed chunk 59/461
# Processed chunk 60/461
# Processed chunk 60/461
# Processed chunk 61/461
# Processed chunk 61/461
# Processed chunk 62/461
# Processed chunk 62/461
# Processed chunk 63/461
# Processed chunk 63/461
# Processed chunk 64/461
# Processed chunk 64/461
# Processed chunk 65/461
# Processed chunk 65/461
# Processed chunk 66/461
# Processed chunk 66/461
# Processed chunk 67/461
# Processed chunk 67/461
# Processed chunk 68/461
# Processed chunk 68/461
# Processed chunk 69/461
# Processed chunk 69/461
# Processed chunk 70/461
# Processed chunk 70/461
# Processed chunk 71/461
# Processed chunk 71/461
# Processed chunk 72/461
# Processed chunk 72/461
# Processed chunk 73/461
# Processed chunk 73/461
# Processed chunk 74/461
# Processed chunk 74/461
# Processed chunk 75/461
# Processed chunk 75/461
# Processed chunk 76/461
# Processed chunk 76/461
# Processed chunk 77/461
# Processed chunk 77/461
# Processed chunk 78/461
# Processed chunk 78/461
# Processed chunk 79/461
# Processed chunk 79/461
# Processed chunk 80/461
# Processed chunk 80/461
# Processed chunk 81/461
# Processed chunk 81/461
# Processed chunk 82/461
# Processed chunk 82/461
# Processed chunk 83/461
# Processed chunk 83/461
# Processed chunk 84/461
# Processed chunk 84/461
# Processed chunk 85/461
# Processed chunk 85/461
# Processed chunk 86/461
# Processed chunk 86/461
# Processed chunk 87/461
# Processed chunk 87/461
# Processed chunk 88/461
# Processed chunk 88/461
# Processed chunk 89/461
# Processed chunk 89/461
# Processed chunk 90/461
# Processed chunk 90/461
# Processed chunk 91/461
# Processed chunk 91/461
# Processed chunk 92/461
# Processed chunk 92/461
# Processed chunk 93/461
# Processed chunk 93/461
# Processed chunk 94/461
# Processed chunk 94/461
# Processed chunk 95/461
# Processed chunk 95/461
# Processed chunk 96/461
# Processed chunk 96/461
# Processed chunk 97/461
# Processed chunk 97/461
# Processed chunk 98/461
# Processed chunk 98/461
# Processed chunk 99/461
# Processed chunk 99/461
# Processed chunk 100/461
# Processed chunk 100/461
# Processed chunk 101/461
# Processed chunk 101/461
# Processed chunk 102/461
# Processed chunk 102/461
# Processed chunk 103/461
# Processed chunk 103/461
# Processed chunk 104/461
# Processed chunk 104/461
# Processed chunk 105/461
# Processed chunk 105/461
# Processed chunk 106/461
# Processed chunk 106/461
# Processed chunk 107/461
# Processed chunk 107/461
# Processed chunk 108/461
# Processed chunk 108/461
# Processed chunk 109/461
# Processed chunk 109/461
# Processed chunk 110/461
# Processed chunk 110/461
# Processed chunk 111/461
# Processed chunk 111/461
# Processed chunk 112/461
# Processed chunk 112/461
# Processed chunk 113/461
# Processed chunk 113/461
# Processed chunk 114/461
# Processed chunk 114/461
# Processed chunk 115/461
# Processed chunk 115/461
# Processed chunk 116/461
# Processed chunk 116/461
# Processed chunk 117/461
# Processed chunk 117/461
# Processed chunk 118/461
# Processed chunk 118/461
# Processed chunk 119/461
# Processed chunk 119/461
# Processed chunk 120/461
# Processed chunk 120/461
# Processed chunk 121/461
# Processed chunk 121/461
# Processed chunk 122/461
# Processed chunk 122/461
# Processed chunk 123/461
# Processed chunk 123/461
# Processed chunk 124/461
# Processed chunk 124/461
# Processed chunk 125/461
# Processed chunk 125/461
# Processed chunk 126/461
# Processed chunk 126/461
# Processed chunk 127/461
# Processed chunk 127/461
# Processed chunk 128/461
# Processed chunk 128/461
# Processed chunk 129/461
# Processed chunk 129/461
# Processed chunk 130/461
# Processed chunk 130/461
# Processed chunk 131/461
# Processed chunk 131/461
# Processed chunk 132/461
# Processed chunk 132/461
# Processed chunk 133/461
# Processed chunk 133/461
# Processed chunk 134/461
# Processed chunk 134/461
# Processed chunk 135/461
# Processed chunk 135/461
# Processed chunk 136/461
# Processed chunk 136/461
# Processed chunk 137/461
# Processed chunk 137/461
# Processed chunk 138/461
# Processed chunk 138/461
# Processed chunk 139/461
# Processed chunk 139/461
# Processed chunk 140/461
# Processed chunk 140/461
# Processed chunk 141/461
# Processed chunk 141/461
# Processed chunk 142/461
# Processed chunk 142/461
# Processed chunk 143/461
# Processed chunk 143/461
# Processed chunk 144/461
# Processed chunk 144/461
# Processed chunk 145/461
# Processed chunk 145/461
# Processed chunk 146/461
# Processed chunk 146/461
# Processed chunk 147/461
# Processed chunk 147/461
# Processed chunk 148/461
# Processed chunk 148/461
# Processed chunk 149/461
# Processed chunk 149/461
# Processed chunk 150/461
# Processed chunk 150/461
# Processed chunk 151/461
# Processed chunk 151/461
# Processed chunk 152/461
# Processed chunk 152/461
# Processed chunk 153/461
# Processed chunk 153/461
# Processed chunk 154/461
# Processed chunk 154/461
# Processed chunk 155/461
# Processed chunk 155/461
# Processed chunk 156/461
# Processed chunk 156/461
# Processed chunk 157/461
# Processed chunk 157/461
# Processed chunk 158/461
# Processed chunk 158/461
# Processed chunk 159/461
# Processed chunk 159/461
# Processed chunk 160/461
# Processed chunk 160/461
# Processed chunk 161/461
# Processed chunk 161/461
# Processed chunk 162/461
# Processed chunk 162/461
# Processed chunk 163/461
# Processed chunk 163/461
# Processed chunk 164/461
# Processed chunk 164/461
# Processed chunk 165/461
# Processed chunk 165/461
# Processed chunk 166/461
# Processed chunk 166/461
# Processed chunk 167/461
# Processed chunk 167/461
# Processed chunk 168/461
# Processed chunk 168/461
# Processed chunk 169/461
# Processed chunk 169/461
# Processed chunk 170/461
# Processed chunk 170/461
# Processed chunk 171/461
# Processed chunk 171/461
# Processed chunk 172/461
# Processed chunk 172/461
# Processed chunk 173/461
# Processed chunk 173/461
# Processed chunk 174/461
# Processed chunk 174/461
# Processed chunk 175/461
# Processed chunk 175/461
# Processed chunk 176/461
# Processed chunk 176/461
# Processed chunk 177/461
# Processed chunk 177/461
# Processed chunk 178/461
# Processed chunk 178/461
# Processed chunk 179/461
# Processed chunk 179/461
# Processed chunk 180/461
# Processed chunk 180/461
# Processed chunk 181/461
# Processed chunk 181/461
# Processed chunk 182/461
# Processed chunk 182/461
# Processed chunk 183/461
# Processed chunk 183/461
# Processed chunk 184/461
# Processed chunk 184/461
# Processed chunk 185/461
# Processed chunk 185/461
# Processed chunk 186/461
# Processed chunk 186/461
# Processed chunk 187/461
# Processed chunk 187/461
# Processed chunk 188/461
# Processed chunk 188/461
# Processed chunk 189/461
# Processed chunk 189/461
# Processed chunk 190/461
# Processed chunk 190/461
# Processed chunk 191/461
# Processed chunk 191/461
# Processed chunk 192/461
# Processed chunk 192/461
# Processed chunk 193/461
# Processed chunk 193/461
# Processed chunk 194/461
# Processed chunk 194/461
# Processed chunk 195/461
# Processed chunk 195/461
# Processed chunk 196/461
# Processed chunk 196/461
# Processed chunk 197/461
# Processed chunk 197/461
# Processed chunk 198/461
# Processed chunk 198/461
# Processed chunk 199/461
# Processed chunk 199/461
# Processed chunk 200/461
# Processed chunk 200/461
# Processed chunk 201/461
# Processed chunk 201/461
# Processed chunk 202/461
# Processed chunk 202/461
# Processed chunk 203/461
# Processed chunk 203/461
# Processed chunk 204/461
# Processed chunk 204/461
# Processed chunk 205/461
# Processed chunk 205/461
# Processed chunk 206/461
# Processed chunk 206/461
# Processed chunk 207/461
# Processed chunk 207/461
# Processed chunk 208/461
# Processed chunk 208/461
# Processed chunk 209/461
# Processed chunk 209/461
# Processed chunk 210/461
# Processed chunk 210/461
# Processed chunk 211/461
# Processed chunk 211/461
# Processed chunk 212/461
# Processed chunk 212/461
# Processed chunk 213/461
# Processed chunk 213/461
# Processed chunk 214/461
# Processed chunk 214/461
# Processed chunk 215/461
# Processed chunk 215/461
# Processed chunk 216/461
# Processed chunk 216/461
# Processed chunk 217/461
# Processed chunk 217/461
# Processed chunk 218/461
# Processed chunk 218/461
# Processed chunk 219/461
# Processed chunk 219/461
# Processed chunk 220/461
# Processed chunk 220/461
# Processed chunk 221/461
# Processed chunk 221/461
# Processed chunk 222/461
# Processed chunk 222/461
# Processed chunk 223/461
# Processed chunk 223/461
# Processed chunk 224/461
# Processed chunk 224/461
# Processed chunk 225/461
# Processed chunk 225/461
# Processed chunk 226/461
# Processed chunk 226/461
# Processed chunk 227/461
# Processed chunk 227/461
# Processed chunk 228/461
# Processed chunk 228/461
# Processed chunk 229/461
# Processed chunk 229/461
# Processed chunk 230/461
# Processed chunk 230/461
# Processed chunk 231/461
# Processed chunk 231/461
# Processed chunk 232/461
# Processed chunk 232/461
# Processed chunk 233/461
# Processed chunk 233/461
# Processed chunk 234/461
# Processed chunk 234/461
# Processed chunk 235/461
# Processed chunk 235/461
# Processed chunk 236/461
# Processed chunk 236/461
# Processed chunk 237/461
# Processed chunk 237/461
# Processed chunk 238/461
# Processed chunk 238/461
# Processed chunk 239/461
# Processed chunk 239/461
# Processed chunk 240/461
# Processed chunk 240/461
# Processed chunk 241/461
# Processed chunk 241/461
# Processed chunk 242/461
# Processed chunk 242/461
# Processed chunk 243/461
# Processed chunk 243/461
# Processed chunk 244/461
# Processed chunk 244/461
# Processed chunk 245/461
# Processed chunk 245/461
# Processed chunk 246/461
# Processed chunk 246/461
# Processed chunk 247/461
# Processed chunk 247/461
# Processed chunk 248/461
# Processed chunk 248/461
# Processed chunk 249/461
# Processed chunk 249/461
# Processed chunk 250/461
# Processed chunk 250/461
# Processed chunk 251/461
# Processed chunk 251/461
# Processed chunk 252/461
# Processed chunk 252/461
# Processed chunk 253/461
# Processed chunk 253/461
# Processed chunk 254/461
# Processed chunk 254/461
# Processed chunk 255/461
# Processed chunk 255/461
# Processed chunk 256/461
# Processed chunk 256/461
# Processed chunk 257/461
# Processed chunk 257/461
# Processed chunk 258/461
# Processed chunk 258/461
# Processed chunk 259/461
# Processed chunk 259/461
# Processed chunk 260/461
# Processed chunk 260/461
# Processed chunk 261/461
# Processed chunk 261/461
# Processed chunk 262/461
# Processed chunk 262/461
# Processed chunk 263/461
# Processed chunk 263/461
# Processed chunk 264/461
# Processed chunk 264/461
# Processed chunk 265/461
# Processed chunk 265/461
# Processed chunk 266/461
# Processed chunk 266/461
# Processed chunk 267/461
# Processed chunk 267/461
# Processed chunk 268/461
# Processed chunk 268/461
# Processed chunk 269/461
# Processed chunk 269/461
# Processed chunk 270/461
# Processed chunk 270/461
# Processed chunk 271/461
# Processed chunk 271/461
# Processed chunk 272/461
# Processed chunk 272/461
# Processed chunk 273/461
# Processed chunk 273/461
# Processed chunk 274/461
# Processed chunk 274/461
# Processed chunk 275/461
# Processed chunk 275/461
# Processed chunk 276/461
# Processed chunk 276/461
# Processed chunk 277/461
# Processed chunk 277/461
# Processed chunk 278/461
# Processed chunk 278/461
# Processed chunk 279/461
# Processed chunk 279/461
# Processed chunk 280/461
# Processed chunk 280/461
# Processed chunk 281/461
# Processed chunk 281/461
# Processed chunk 282/461
# Processed chunk 282/461
# Processed chunk 283/461
# Processed chunk 283/461
# Processed chunk 284/461
# Processed chunk 284/461
# Processed chunk 285/461
# Processed chunk 285/461
# Processed chunk 286/461
# Processed chunk 286/461
# Processed chunk 287/461
# Processed chunk 287/461
# Processed chunk 288/461
# Processed chunk 288/461
# Processed chunk 289/461
# Processed chunk 289/461
# Processed chunk 290/461
# Processed chunk 290/461
# Processed chunk 291/461
# Processed chunk 291/461
# Processed chunk 292/461
# Processed chunk 292/461
# Processed chunk 293/461
# Processed chunk 293/461
# Processed chunk 294/461
# Processed chunk 294/461
# Processed chunk 295/461
# Processed chunk 295/461
# Processed chunk 296/461
# Processed chunk 296/461
# Processed chunk 297/461
# Processed chunk 297/461
# Processed chunk 298/461
# Processed chunk 298/461
# Processed chunk 299/461
# Processed chunk 299/461
# Processed chunk 300/461
# Processed chunk 300/461
# Processed chunk 301/461
# Processed chunk 301/461
# Processed chunk 302/461
# Processed chunk 302/461
# Processed chunk 303/461
# Processed chunk 303/461
# Processed chunk 304/461
# Processed chunk 304/461
# Processed chunk 305/461
# Processed chunk 305/461
# Processed chunk 306/461
# Processed chunk 306/461
# Processed chunk 307/461
# Processed chunk 307/461
# Processed chunk 308/461
# Processed chunk 308/461
# Processed chunk 309/461
# Processed chunk 309/461
# Processed chunk 310/461
# Processed chunk 310/461
# Processed chunk 311/461
# Processed chunk 311/461
# Processed chunk 312/461
# Processed chunk 312/461
# Processed chunk 313/461
# Processed chunk 313/461
# Processed chunk 314/461
# Processed chunk 314/461
# Processed chunk 315/461
# Processed chunk 315/461
# Processed chunk 316/461
# Processed chunk 316/461
# Processed chunk 317/461
# Processed chunk 317/461
# Processed chunk 318/461
# Processed chunk 318/461
# Processed chunk 319/461
# Processed chunk 319/461
# Processed chunk 320/461
# Processed chunk 320/461
# Processed chunk 321/461
# Processed chunk 321/461
# Processed chunk 322/461
# Processed chunk 322/461
# Processed chunk 323/461
# Processed chunk 323/461
# Processed chunk 324/461
# Processed chunk 324/461
# Processed chunk 325/461
# Processed chunk 325/461
# Processed chunk 326/461
# Processed chunk 326/461
# Processed chunk 327/461
# Processed chunk 327/461
# Processed chunk 328/461
# Processed chunk 328/461
# Processed chunk 329/461
# Processed chunk 329/461
# Processed chunk 330/461
# Processed chunk 330/461
# Processed chunk 331/461
# Processed chunk 331/461
# Processed chunk 332/461
# Processed chunk 332/461
# Processed chunk 333/461
# Processed chunk 333/461
# Processed chunk 334/461
# Processed chunk 334/461
# Processed chunk 335/461
# Processed chunk 335/461
# Processed chunk 336/461
# Processed chunk 336/461
# Processed chunk 337/461
# Processed chunk 337/461
# Processed chunk 338/461
# Processed chunk 338/461
# Processed chunk 339/461
# Processed chunk 339/461
# Processed chunk 340/461
# Processed chunk 340/461
# Processed chunk 341/461
# Processed chunk 341/461
# Processed chunk 342/461
# Processed chunk 342/461
# Processed chunk 343/461
# Processed chunk 343/461
# Processed chunk 344/461
# Processed chunk 344/461
# Processed chunk 345/461
# Processed chunk 345/461
# Processed chunk 346/461
# Processed chunk 346/461
# Processed chunk 347/461
# Processed chunk 347/461
# Processed chunk 348/461
# Processed chunk 348/461
# Processed chunk 349/461
# Processed chunk 349/461
# Processed chunk 350/461
# Processed chunk 350/461
# Processed chunk 351/461
# Processed chunk 351/461
# Processed chunk 352/461
# Processed chunk 352/461
# Processed chunk 353/461
# Processed chunk 353/461
# Processed chunk 354/461
# Processed chunk 354/461
# Processed chunk 355/461
# Processed chunk 355/461
# Processed chunk 356/461
# Processed chunk 356/461
# Processed chunk 357/461
# Processed chunk 357/461
# Processed chunk 358/461
# Processed chunk 358/461
# Processed chunk 359/461
# Processed chunk 359/461
# Processed chunk 360/461
# Processed chunk 360/461
# Processed chunk 361/461
# Processed chunk 361/461
# Processed chunk 362/461
# Processed chunk 362/461
# Processed chunk 363/461
# Processed chunk 363/461
# Processed chunk 364/461
# Processed chunk 364/461
# Processed chunk 365/461
# Processed chunk 365/461
# Processed chunk 366/461
# Processed chunk 366/461
# Processed chunk 367/461
# Processed chunk 367/461
# Processed chunk 368/461
# Processed chunk 368/461
# Processed chunk 369/461
# Processed chunk 369/461
# Processed chunk 370/461
# Processed chunk 370/461
# Processed chunk 371/461
# Processed chunk 371/461
# Processed chunk 372/461
# Processed chunk 372/461
# Processed chunk 373/461
# Processed chunk 373/461
# Processed chunk 374/461
# Processed chunk 374/461
# Processed chunk 375/461
# Processed chunk 375/461
# Processed chunk 376/461
# Processed chunk 376/461
# Processed chunk 377/461
# Processed chunk 377/461
# Processed chunk 378/461
# Processed chunk 378/461
# Processed chunk 379/461
# Processed chunk 379/461
# Processed chunk 380/461
# Processed chunk 380/461
# Processed chunk 381/461
# Processed chunk 381/461
# Processed chunk 382/461
# Processed chunk 382/461
# Processed chunk 383/461
# Processed chunk 383/461
# Processed chunk 384/461
# Processed chunk 384/461
# Processed chunk 385/461
# Processed chunk 385/461
# Processed chunk 386/461
# Processed chunk 386/461
# Processed chunk 387/461
# Processed chunk 387/461
# Processed chunk 388/461
# Processed chunk 388/461
# Processed chunk 389/461
# Processed chunk 389/461
# Processed chunk 390/461
# Processed chunk 390/461
# Processed chunk 391/461
# Processed chunk 391/461
# Processed chunk 392/461
# Processed chunk 392/461
# Processed chunk 393/461
# Processed chunk 393/461
# Processed chunk 394/461
# Processed chunk 394/461
# Processed chunk 395/461
# Processed chunk 395/461
# Processed chunk 396/461
# Processed chunk 396/461
# Processed chunk 397/461
# Processed chunk 397/461
# Processed chunk 398/461
# Processed chunk 398/461
# Processed chunk 399/461
# Processed chunk 399/461
# Processed chunk 400/461
# Processed chunk 400/461
# Processed chunk 401/461
# Processed chunk 401/461
# Processed chunk 402/461
# Processed chunk 402/461
# Processed chunk 403/461
# Processed chunk 403/461
# Processed chunk 404/461
# Processed chunk 404/461
# Processed chunk 405/461
# Processed chunk 405/461
# Processed chunk 406/461
# Processed chunk 406/461
# Processed chunk 407/461
# Processed chunk 407/461
# Processed chunk 408/461
# Processed chunk 408/461
# Processed chunk 409/461
# Processed chunk 409/461
# Processed chunk 410/461
# Processed chunk 410/461
# Processed chunk 411/461
# Processed chunk 411/461
# Processed chunk 412/461
# Processed chunk 412/461
# Processed chunk 413/461
# Processed chunk 413/461
# Processed chunk 414/461
# Processed chunk 414/461
# Processed chunk 415/461
# Processed chunk 415/461
# Processed chunk 416/461
# Processed chunk 416/461
# Processed chunk 417/461
# Processed chunk 417/461
# Processed chunk 418/461
# Processed chunk 418/461
# Processed chunk 419/461
# Processed chunk 419/461
# Processed chunk 420/461
# Processed chunk 420/461
# Processed chunk 421/461
# Processed chunk 421/461
# Processed chunk 422/461
# Processed chunk 422/461
# Processed chunk 423/461
# Processed chunk 423/461
# Processed chunk 424/461
# Processed chunk 424/461
# Processed chunk 425/461
# Processed chunk 425/461
# Processed chunk 426/461
# Processed chunk 426/461
# Processed chunk 427/461
# Processed chunk 427/461
# Processed chunk 428/461
# Processed chunk 428/461
# Processed chunk 429/461
# Processed chunk 429/461
# Processed chunk 430/461
# Processed chunk 430/461
# Processed chunk 431/461
# Processed chunk 431/461
# Processed chunk 432/461
# Processed chunk 432/461
# Processed chunk 433/461
# Processed chunk 433/461
# Processed chunk 434/461
# Processed chunk 434/461
# Processed chunk 435/461
# Processed chunk 435/461
# Processed chunk 436/461
# Processed chunk 436/461
# Processed chunk 437/461
# Processed chunk 437/461
# Processed chunk 438/461
# Processed chunk 438/461
# Processed chunk 439/461
# Processed chunk 439/461
# Processed chunk 440/461
# Processed chunk 440/461
# Processed chunk 441/461
# Processed chunk 441/461
# Processed chunk 442/461
# Processed chunk 442/461
# Processed chunk 443/461
# Processed chunk 443/461
# Processed chunk 444/461
# Processed chunk 444/461
# Processed chunk 445/461
# Processed chunk 445/461
# Processed chunk 446/461
# Processed chunk 446/461
# Processed chunk 447/461
# Processed chunk 447/461
# Processed chunk 448/461
# Processed chunk 448/461
# Processed chunk 449/461
# Processed chunk 449/461
# Processed chunk 450/461
# Processed chunk 450/461
# Processed chunk 451/461
# Processed chunk 451/461
# Processed chunk 452/461
# Processed chunk 452/461
# Processed chunk 453/461
# Processed chunk 453/461
# Processed chunk 454/461
# Processed chunk 454/461
# Processed chunk 455/461
# Processed chunk 455/461
# Processed chunk 456/461
# Processed chunk 456/461
# Processed chunk 457/461
# Processed chunk 457/461
# Processed chunk 458/461
# Processed chunk 458/461
# Processed chunk 459/461
# Processed chunk 459/461
# Processed chunk 460/461
# Processed chunk 460/461
# Processed chunk 461/461
# Processed chunk 461/461

# %%
data = pd.read_csv(csv_file)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23036 entries, 0 to 23035
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   project         23036 non-null  object
#  1   issue_number    23036 non-null  int64
#  2   issue_type      23036 non-null  object
#  3   text            23036 non-null  object
#  4   classification  23036 non-null  object
#  5   indicator       23036 non-null  object
#  6   sentiment       23036 non-null  object
#  7   score           23036 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ MB
